# %%
#%% Importing
from  funcs import *
import numpy as np
import matplotlib.pylab as plt
from scipy import signal
import seaborn as sns
import pandas as pd

# %%
#%% Initiation
main_dir = r'D:\University\Khaje\Semester 1\کنترل سیستم های عصبی عضلانی\Assymetry Project\Datas\All'
file_names = os.listdir(main_dir)

# %%
df = pd.read_excel(os.path.join(main_dir,file_names[4]), header=1)

# %%
file_names
# Out:
# ['brace fast_Joints_Kinematics.xlsx',
#  'brace normal_Joints_Kinematics.xlsx',
#  'brace weight fast_Joints_Kinematics.xlsx',
#  'brace weight normal_Joints_Kinematics.xlsx',
#  'Wakling normal_Joints_Kinematics.xlsx',
#  'walking fast_Joints_Kinematics.xlsx',
#  'weight fast_Joints_Kinematics.xlsx',
#  'weight normal_Joints_Kinematics.xlsx']

# %%
df = pd.read_excel(os.path.join(main_dir,file_names[4]), header=1)

# %%
df
# Out:
#        78905  -2.110077854  10.23398468  3.423338753  78905.1  0.798900275  \
# 0      78911     -2.051537    10.248214     3.431123    78911     0.780223
# 1      78917     -2.061584    10.256265     3.438109    78917     0.771668
# 2      78923     -2.119324    10.230538     3.438281    78923     0.764873
# 3      78929     -2.165318    10.209449     3.439314    78929     0.763415
# 4      78935     -2.195444    10.202418     3.446353    78935     0.783753
# ...      ...           ...          ...          ...      ...          ...
# 8593  130469     -6.524931     5.538301    10.177752   130469     5.387608
# 8594  130475     -7.392803     5.601340    10.270198   130475     5.743656
# 8595  130481     -8.210772     5.629388    10.383050   130481     6.062894
# 8596  130487     -8.980995     5.645249    10.498503   130487     6.278247
# 8597  130493     -9.719139     5.605204    10.592385   130493     6.391740
#
#       -14.08922136  0.503696219  78905.2  0.737451274  ...  -15.32084559  \
# 0       -14.081747     0.500898    78911     0.741433  ...    -15.315411
# 1       -14.080030     0.496889    78917     0.745730  ...    -15.310006
# 2       -14.079088     0.492655    78923     0.733704  ...    -15.330053
# 3       -14.080115     0.485506    78929     0.721193  ...    -15.349480
# 4       -14.090762     0.483272    78935     0.709174  ...    -15.355090
# ...            ...          ...      ...          ...  ...           ...
# 8593      4.295341    15.469439   130469     1.207283  ...     -5.602835
# 8594      4.508048    15.349496   130475     1.315684  ...     -5.485301
# 8595      4.724273    15.179153   130481     1.377480  ...     -5.378493
# 8596      4.957907    14.928219   130487     1.372965  ...     -5.264748
# 8597      5.197247    14.604084   130493     1.337274  ...     -5.153903
#
#       2.489203415  78905.8  0.501723458  -10.53817612  2.733180418  78905.9  \
# 0        2.492494    78911     0.525940    -10.524668     2.722205    78911
# 1        2.495859    78917     0.499495    -10.541246     2.704484    78917
# 2        2.495190    78923     0.431591    -10.591177     2.682481    78923
# 3        2.494415    78929     0.369504    -10.636167     2.663872    78929
# 4        2.497691    78935     0.331666    -10.664418     2.653052    78935
# ...           ...      ...          ...           ...          ...      ...
# 8593     9.516052   130469    -4.429736     25.054224     4.095249   130469
# 8594     9.735211   130475    -4.361858     25.132477     5.004833   130475
# 8595     9.931635   130481    -4.301111     25.169126     5.900041   130481
# 8596    10.083313   130487    -4.240450     25.192577     6.768139   130487
# 8597    10.193135   130493    -4.209331     25.173866     7.587363   130493
#
#       0.461404182  11.69946358  -0.238258535
# 0        0.447563    11.691151     -0.237097
# 1        0.441677    11.688028     -0.232629
# 2        0.424248    11.676043     -0.226589
# 3        0.411672    11.664540     -0.219916
# 4        0.420985    11.662341     -0.213157
# ...           ...          ...           ...
# 8593     1.258415   -21.193423     -6.389355
# 8594     1.348272   -20.818448     -6.453330
# 8595     1.324728   -20.439277     -6.586947
# 8596     1.208275   -20.073418     -6.769781
# 8597     1.032402   -19.744916     -6.968676
#
# [8598 rows x 40 columns]

# %%
# Reading a data
df1 = pd.read_excel('brace fast_Joints_Kinematics.xlsx', header=1)

# %%
df1
# Out:
#       RightHip_Time  RightHip_Abduction-Adduction  \
# 0            254403                     -2.059231
# 1            254409                     -2.039962
# 2            254415                     -2.020533
# 3            254421                     -1.995142
# 4            254427                     -1.971797
# ...             ...                           ...
# 6394         292766                      0.416470
# 6395         292772                      0.821438
# 6396         292778                      1.198213
# 6397         292784                      1.573576
# 6398         292790                      1.927473
#
#       RightHip_Internal-External Rotat  RightHip_Flexion-Extension  \
# 0                            20.544484                   -4.393238
# 1                            20.557440                   -4.399209
# 2                            20.571043                   -4.407936
# 3                            20.588525                   -4.418874
# 4                            20.603148                   -4.431546
# ...                                ...                         ...
# 6394                          5.541789                  -11.702039
# 6395                          5.963035                  -11.007131
# 6396                          6.393711                  -10.318424
# 6397                          6.795259                   -9.656930
# 6398                          7.168305                   -9.007811
#
#       LeftShoulder_Time  LeftShoulder_Abduction-Adduction  \
# 0                254403                         -5.308551
# 1                254409                         -5.295008
# 2                254415                         -5.267304
# 3                254421                         -5.268354
# 4                254427                         -5.270430
# ...                 ...                               ...
# 6394             292766                        -11.187422
# 6395             292772                        -10.991225
# 6396             292778                        -10.745569
# 6397             292784                        -10.448508
# 6398             292790                        -10.103080
#
#       LeftShoulder_Internal-External Rotat  LeftShoulder_Flexion-Extension  \
# 0                               -61.341742                        3.905030
# 1                               -61.316556                        3.918053
# 2                               -61.281488                        3.931139
# 3                               -61.264887                        3.936789
# 4                               -61.253488                        3.938213
# ...                                    ...                             ...
# 6394                            -46.318389                      -18.250839
# 6395                            -46.358233                      -17.968481
# 6396                            -46.359219                      -17.585368
# 6397                            -46.318370                      -17.100623
# 6398                            -46.205282                      -16.509239
#
#       RightShoulder_Time  RightShoulder_Abduction-Adduction  ...  \
# 0                 254403                          -2.119546  ...
# 1                 254409                          -2.103434  ...
# 2                 254415                          -2.072729  ...
# 3                 254421                          -2.073092  ...
# 4                 254427                          -2.071466  ...
# ...                  ...                                ...  ...
# 6394              292766                           7.870304  ...
# 6395              292772                           7.474485  ...
# 6396              292778                           7.102008  ...
# 6397              292784                           6.751714  ...
# 6398              292790                           6.450204  ...
#
#       LeftHip_Internal-External Rotat  LeftHip_Flexion-Extension  \
# 0                          -18.376024                   0.840305
# 1                          -18.378295                   0.840875
# 2                          -18.409197                   0.827441
# 3                          -18.350233                   0.837558
# 4                          -18.293476                   0.846774
# ...                               ...                        ...
# 6394                       -17.657329                 -18.357646
# 6395                       -17.226707                 -17.876867
# 6396                       -16.734710                 -17.278722
# 6397                       -16.359578                 -16.693328
# 6398                       -16.167943                 -16.137828
#
#       RightAnkle_Time  RightAnkle_Abduction-Adduction  \
# 0              254403                        0.645748
# 1              254409                        0.665835
# 2              254415                        0.684267
# 3              254421                        0.698452
# 4              254427                        0.714201
# ...               ...                             ...
# 6394           292766                       -1.974311
# 6395           292772                       -1.171924
# 6396           292778                       -0.531134
# 6397           292784                        0.054700
# 6398           292790                        0.549796
#
#       RightAnkle_Internal-External Rotat  RightAnkle_Flexion-Extension  \
# 0                              17.907830                     -0.562399
# 1                              17.927843                     -0.566914
# 2                              17.948134                     -0.569308
# 3                              17.965962                     -0.571785
# 4                              17.982943                     -0.575624
# ...                                  ...                           ...
# 6394                          -24.171612                      3.746401
# 6395                          -24.085149                      5.560855
# 6396                          -23.735602                      7.439481
# 6397                          -23.232924                      9.197941
# 6398                          -22.606165                     10.872562
#
#       LeftAnkle_Time  LeftAnkle_Abduction-Adduction  \
# 0             254403                       2.201472
# 1             254409                       2.215687
# 2             254415                       2.263926
# 3             254421                       2.311191
# 4             254427                       2.313176
# ...              ...                            ...
# 6394          292766                       4.307003
# 6395          292772                       4.127430
# 6396          292778                       4.321734
# 6397          292784                       4.770647
# 6398          292790                       5.350177
#
#       LeftAnkle_Internal-External Rotat  LeftAnkle_Flexion-Extension
# 0                            -15.999391                    -3.544932
# 1                            -16.007320                    -3.551448
# 2                            -16.032442                    -3.564957
# 3                            -16.057776                    -3.576170
# 4                            -16.062123                    -3.575482
# ...                                 ...                          ...
# 6394                          15.799183                     4.162250
# 6395                          15.869853                     3.266611
# 6396                          16.408488                     2.824078
# 6397                          17.359840                     2.724412
# 6398                          18.546485                     2.909255
#
# [6399 rows x 40 columns]

# %%
# Creating gaitData obejct out of the main dataframe
test_df = gaitData(df)
test_df.detrend()

# %%
# Extracting limits
cycle_lim = lim_ex(test_df)

# %%
# Segmentation
cycles = Cycles(test_df, cycle_lim)

# %%
#%% Plotting
x = cycles.right_knee.sagittal
t = cycles.right_knee.time
plt.figure(figsize=(22,8))
for i in range(len(x)):
    
    plt.plot(t[i],x[i])

# %%
cycles.right_hip.iloc[3].time
# Out:
# 262    1.572
# 263    1.578
# 264    1.584
# 265    1.590
# 266    1.596
#        ...
# 520    3.120
# 521    3.126
# 522    3.132
# 523    3.138
# 524    3.144
# Name: time, Length: 263, dtype: float64

# %%
X = cycles.right_knee.iloc[4].sagittal
T = cycles.right_knee.iloc[4].time
plt.figure(figsize=(22,8))
plt.plot(T,X)

# %%
type(cycles.left_ankle)
# Out:
# pandas.core.frame.DataFrame
