# %%
#%% Importing
from  funcs import *
import numpy as np
import matplotlib.pylab as plt
from scipy import signal
import seaborn as sns
import pandas as pd

# %%
#%% Initiation
main_dir = r'D:\University\Khaje\Semester 1\کنترل سیستم های عصبی عضلانی\Assymetry Project\Datas\All'
file_names = os.listdir(main_dir)

# %%
df = pd.read_excel(os.path.join(main_dir,file_names[7]), header=1)

# %%
file_names
# Out:
# ['brace fast_Joints_Kinematics.xlsx',
#  'brace normal_Joints_Kinematics.xlsx',
#  'brace weight fast_Joints_Kinematics.xlsx',
#  'brace weight normal_Joints_Kinematics.xlsx',
#  'Wakling normal_Joints_Kinematics.xlsx',
#  'walking fast_Joints_Kinematics.xlsx',
#  'weight fast_Joints_Kinematics.xlsx',
#  'weight normal_Joints_Kinematics.xlsx',
#  '~$brace fast_Joints_Kinematics.xlsx']

# %%
df = pd.read_excel(os.path.join(main_dir,file_names[0]), header=1)

# %%
df
# Out:
#       RightHip_Time  RightHip_Abduction-Adduction  \
# 0            254403                     -2.059231
# 1            254409                     -2.039962
# 2            254415                     -2.020533
# 3            254421                     -1.995142
# 4            254427                     -1.971797
# ...             ...                           ...
# 6394         292766                      0.416470
# 6395         292772                      0.821438
# 6396         292778                      1.198213
# 6397         292784                      1.573576
# 6398         292790                      1.927473
#
#       RightHip_Internal-External Rotat  RightHip_Flexion-Extension  \
# 0                            20.544484                   -4.393238
# 1                            20.557440                   -4.399209
# 2                            20.571043                   -4.407936
# 3                            20.588525                   -4.418874
# 4                            20.603148                   -4.431546
# ...                                ...                         ...
# 6394                          5.541789                  -11.702039
# 6395                          5.963035                  -11.007131
# 6396                          6.393711                  -10.318424
# 6397                          6.795259                   -9.656930
# 6398                          7.168305                   -9.007811
#
#       LeftShoulder_Time  LeftShoulder_Abduction-Adduction  \
# 0                254403                         -5.308551
# 1                254409                         -5.295008
# 2                254415                         -5.267304
# 3                254421                         -5.268354
# 4                254427                         -5.270430
# ...                 ...                               ...
# 6394             292766                        -11.187422
# 6395             292772                        -10.991225
# 6396             292778                        -10.745569
# 6397             292784                        -10.448508
# 6398             292790                        -10.103080
#
#       LeftShoulder_Internal-External Rotat  LeftShoulder_Flexion-Extension  \
# 0                               -61.341742                        3.905030
# 1                               -61.316556                        3.918053
# 2                               -61.281488                        3.931139
# 3                               -61.264887                        3.936789
# 4                               -61.253488                        3.938213
# ...                                    ...                             ...
# 6394                            -46.318389                      -18.250839
# 6395                            -46.358233                      -17.968481
# 6396                            -46.359219                      -17.585368
# 6397                            -46.318370                      -17.100623
# 6398                            -46.205282                      -16.509239
#
#       RightShoulder_Time  RightShoulder_Abduction-Adduction  ...  \
# 0                 254403                          -2.119546  ...
# 1                 254409                          -2.103434  ...
# 2                 254415                          -2.072729  ...
# 3                 254421                          -2.073092  ...
# 4                 254427                          -2.071466  ...
# ...                  ...                                ...  ...
# 6394              292766                           7.870304  ...
# 6395              292772                           7.474485  ...
# 6396              292778                           7.102008  ...
# 6397              292784                           6.751714  ...
# 6398              292790                           6.450204  ...
#
#       LeftHip_Internal-External Rotat  LeftHip_Flexion-Extension  \
# 0                          -18.376024                   0.840305
# 1                          -18.378295                   0.840875
# 2                          -18.409197                   0.827441
# 3                          -18.350233                   0.837558
# 4                          -18.293476                   0.846774
# ...                               ...                        ...
# 6394                       -17.657329                 -18.357646
# 6395                       -17.226707                 -17.876867
# 6396                       -16.734710                 -17.278722
# 6397                       -16.359578                 -16.693328
# 6398                       -16.167943                 -16.137828
#
#       RightAnkle_Time  RightAnkle_Abduction-Adduction  \
# 0              254403                        0.645748
# 1              254409                        0.665835
# 2              254415                        0.684267
# 3              254421                        0.698452
# 4              254427                        0.714201
# ...               ...                             ...
# 6394           292766                       -1.974311
# 6395           292772                       -1.171924
# 6396           292778                       -0.531134
# 6397           292784                        0.054700
# 6398           292790                        0.549796
#
#       RightAnkle_Internal-External Rotat  RightAnkle_Flexion-Extension  \
# 0                              17.907830                     -0.562399
# 1                              17.927843                     -0.566914
# 2                              17.948134                     -0.569308
# 3                              17.965962                     -0.571785
# 4                              17.982943                     -0.575624
# ...                                  ...                           ...
# 6394                          -24.171612                      3.746401
# 6395                          -24.085149                      5.560855
# 6396                          -23.735602                      7.439481
# 6397                          -23.232924                      9.197941
# 6398                          -22.606165                     10.872562
#
#       LeftAnkle_Time  LeftAnkle_Abduction-Adduction  \
# 0             254403                       2.201472
# 1             254409                       2.215687
# 2             254415                       2.263926
# 3             254421                       2.311191
# 4             254427                       2.313176
# ...              ...                            ...
# 6394          292766                       4.307003
# 6395          292772                       4.127430
# 6396          292778                       4.321734
# 6397          292784                       4.770647
# 6398          292790                       5.350177
#
#       LeftAnkle_Internal-External Rotat  LeftAnkle_Flexion-Extension
# 0                            -15.999391                    -3.544932
# 1                            -16.007320                    -3.551448
# 2                            -16.032442                    -3.564957
# 3                            -16.057776                    -3.576170
# 4                            -16.062123                    -3.575482
# ...                                 ...                          ...
# 6394                          15.799183                     4.162250
# 6395                          15.869853                     3.266611
# 6396                          16.408488                     2.824078
# 6397                          17.359840                     2.724412
# 6398                          18.546485                     2.909255
#
# [6399 rows x 40 columns]

# %%
# Creating gaitData obejct out of the main dataframe
test_df = gaitData(df)
test_df.detrend()

# %%
# Extracting limits
cycle_lim = lim_ex(test_df)

# %%
# Segmentation
cycles = Cycles(test_df, cycle_lim)

# %%
#%% Plotting
x = cycles.left_hip.sagittal
t = cycles.left_hip.time
plt.figure(figsize=(22,8))
for i in range(len(x)):
    
    plt.plot(t[i],x[i])

# %% [markdown]
# # Ankle Compare

# %%
Xr = cycles.right_ankle.iloc[2].frontal
Tr = cycles.right_ankle.iloc[2].time
Xl = -cycles.left_ankle.iloc[2].frontal
Tl = cycles.left_ankle.iloc[2].time
plt.figure(figsize=(22,8))
plt.plot(Tr,Xr)
plt.plot(Tl,Xl)

# %% [markdown]
# # Hip Compare

# %%
Xr = cycles.right_hip.iloc[5].sagittal
Tr = cycles.right_hip.iloc[5].time
Xl = -cycles.left_hip.iloc[5].sagittal
Tl = cycles.left_hip.iloc[5].time
plt.figure(figsize=(22,8))
plt.plot(Tr,Xr)
plt.plot(Tl,Xl)

# %% [markdown]
# # Knee Compare

# %%
Xr = cycles.right_knee.iloc[5].sagittal
Tr = cycles.right_knee.iloc[5].time
Xl = -cycles.left_knee.iloc[5].sagittal
Tl = cycles.left_knee.iloc[5].time
plt.figure(figsize=(22,8))
plt.plot(Tr,Xr)
plt.plot(Tl,Xl)

# %% [markdown]
# # Shoulder Compare

# %%
Xr = cycles.right_shoulder.iloc[5].sagittal
Tr = cycles.right_shoulder.iloc[5].time
Xl = -cycles.left_shoulder.iloc[5].sagittal
Tl = cycles.left_shoulder.iloc[5].time
plt.figure(figsize=(22,8))
plt.plot(Tr,Xr)
plt.plot(Tl,Xl)

# %%
cycles.limits
# Out:
# [(25, 50),
#  (51, 311),
#  (312, 486),
#  (487, 660),
#  (661, 837),
#  (838, 1009),
#  (1010, 1183),
#  (1184, 1354),
#  (1355, 1524),
#  (1525, 1702),
#  (1703, 1875),
#  (1876, 2047),
#  (2048, 2225),
#  (2226, 2398),
#  (2399, 2567),
#  (2568, 2744),
#  (2745, 2916),
#  (2917, 3093),
#  (3094, 3265),
#  (3266, 3432),
#  (3433, 3607),
#  (3608, 3779),
#  (3780, 3953),
#  (3954, 4129),
#  (4130, 4299),
#  (4300, 4470),
#  (4471, 4646),
#  (4647, 4822),
#  (4823, 4995),
#  (4996, 5165),
#  (5166, 5335),
#  (5336, 5505),
#  (5506, 5671),
#  (5672, 5843),
#  (5844, 6017),
#  (6018, 6190),
#  (6191, 6368),
#  (6369, 6540),
#  (6541, 6712),
#  (6713, 6885),
#  (6886, 7057),
#  (7058, 7227),
#  (7228, 7407),
#  (7408, 7573)]

# %%
cycles.right_shoulder.iloc[5]
# Out:
# time          838     5.028
# 839     5.034
# 840     5.040
# 841 ...
# frontal       838    -5.419777
# 839    -5.517671
# 840    -5.59...
# horizontal    838    -0.418750
# 839    -0.167043
# 840     0.10...
# sagittal      838    -11.790313
# 839    -12.301566
# 840    -12...
# Name: 5, dtype: object
